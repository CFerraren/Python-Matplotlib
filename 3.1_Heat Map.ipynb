# %%
# Import Numpy for calculations and matplotlib for charting

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


#prettify the plot
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
# Create Synthetic Data

df = pd.DataFrame(np.random.randint(100,size=(10000,2)), columns=['male','female'])
df.head()
# Out:
#    male  female
# 0    49      99
# 1    64      86
# 2    87      52
# 3    45      71
# 4    68      86

# %%
#Plot Scatter Plot

df.plot.scatter(x= 'male', y ='female')

# %% [markdown]
# > With scatter plot, it is hard to find the concentration for large data points

# %%
#Add new columns 'Score'

df['score'] = df.male * 0.3 + df.female * 0.7

# %%
df.head()
# Out:
#    male  female  score
# 0    49      99   84.0
# 1    64      86   79.4
# 2    87      52   62.5
# 3    45      71   63.2
# 4    68      86   80.6

# %%
#Plot Scatter Plot
df.plot.scatter(x= 'male', y ='female', s=df.score)

# %% [markdown]
# #### Using Heatmap

# %%
#Plot Scatter Plot
plt.figure()
df.plot.scatter(x= 'male', y ='female', s=df.score)
plt.savefig('Resources/pltsave/heatMap.png', bbox_inches='tight')
